# %% [markdown]
# # Run the DCAE model
# This notebook offers the possibility to train the DCAE model using Google Drive's GPU to accelerate the training.

# %%
# Librairies pour se connecter au drive: 
from google.colab import drive
import os

# Connexion au drive:
drive.mount('/content/drive', force_remount=True) 

# Chemin du dossier contenant le projet: 
PATH = '/content/drive/My Drive/' + "SII_comportement_vol_ST"

CODE_PATH = PATH + "/code/utilities"
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir(CODE_PATH)
import tensorflow.keras.models as km
import tensorflow.keras.layers as kl
import numpy as np
import tensorflow
tensorflow.__version__

from model_DCAE import main_DCAE
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17863511892140550496
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14415560704
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10557508669179911199
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# GPU

# %%
# choose the parameters 
arch = 1 # architecture of the DCAE : 1 or 2

main_DCAE(arch=arch,
          file_name='encoder_architecture'+str(arch)+'_epoch25_encod'+str(size_encode)+'.h5',
          epochs=25,
          batch_size=10)
# Out:
# Model: "conv_encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_64 (Conv2D)          (None, 22, 206, 76)       57836
#
#  conv2d_65 (Conv2D)          (None, 22, 206, 64)       48704
#
#  conv2d_66 (Conv2D)          (None, 22, 206, 128)      82048
#
#  conv2d_67 (Conv2D)          (None, 22, 206, 128)      49280
#
#  dense_24 (Dense)            (None, 22, 206, 384)      49536
#
#  dense_25 (Dense)            (None, 22, 206, 30)       11550
#
# ...
# Total params: 298,954
# Trainable params: 298,954
# Non-trainable params: 0
# _________________________________________________________________
# Model: "conv_decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_26 (Dense)            (None, 22, 206, 384)      11904
#
#  conv2d_68 (Conv2D)          (None, 22, 206, 128)      147584
#
# ...
